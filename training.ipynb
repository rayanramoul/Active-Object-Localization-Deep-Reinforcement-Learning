# %%
# -*- coding: utf-8 -*-
from utils.agent import *
from utils.dataset import *



from IPython.display import clear_output

import sys
import traceback
import sys
import os
import tqdm.notebook as tq
import seaborn as sns

#!pip3 install torch==1.5.1 torchvision==0.6.1 -f https://download.pytorch.org/whl/cu92/torch_stable.html
try:
    if 'google.colab' in str(get_ipython()):
        from google.colab import drive
        drive.mount('/content/gdrive')
        LOAD = True
        SAVE_MODEL_PATH = '/content/gdrive/MyDrive/models/' + 'q_network'
    else:
        LOAD = False
        SAVE_MODEL_PATH = "./models/q_network"
except NameError:
        LOAD = False
        SAVE_MODEL_PATH = "./models/q_network"
batch_size = 32
PATH="./datasets/"



train_loader2012, val_loader2012 = read_voc_dataset(download=LOAD, year='2012')
train_loader2007, val_loader2007 = read_voc_dataset(download=LOAD, year='2007')

# %%
# 'cat', 'dog', 'bird', 'motorbike', Deja fait
classes = [ 'diningtable', 'train', 'tvmonitor', 'bus', 'horse', 'car', 'pottedplant', 'person', 'chair', 'boat', 'bottle', 'bicycle', 'aeroplane', 'cow', 'sheep', 'sofa']


agents_per_class = {}
datasets_per_class = sort_class_extract([train_loader2007, train_loader2012])
datasets_eval_per_class = sort_class_extract([val_loader2007, val_loader2012])

# %%
for i in tq.tqdm(range(len(classes))):
    classe = classes[i]
    print("Classe "+str(classe)+"...")
    agents_per_class[classe] = Agent(classe, alpha=0.2, num_episodes=15, load=False)
    agents_per_class[classe].train(datasets_per_class[classe])
    del agents_per_class[classe]
    torch.cuda.empty_cache()
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# Classe diningtable...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe train...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe tvmonitor...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe bus...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe horse...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe car...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe pottedplant...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe person...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe chair...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe boat...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe bottle...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe bicycle...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe aeroplane...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe cow...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe sheep...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
# Classe sofa...
# Episode 0
# Saved
# Complete
# Episode 1
# Saved
# Complete
# Episode 2
# Saved
# Complete
# Episode 3
# Saved
# Complete
# Episode 4
# Saved
# Complete
# Episode 5
# Saved
# Complete
# Episode 6
# Saved
# Complete
# Episode 7
# Saved
# Complete
# Episode 8
# Saved
# Complete
# Episode 9
# Saved
# Complete
# Episode 10
# Saved
# Complete
# Episode 11
# Saved
# Complete
# Episode 12
# Saved
# Complete
# Episode 13
# Saved
# Complete
# Episode 14
# Saved
# Complete
